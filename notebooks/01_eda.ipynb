# %%
# Análisis Exploratorio Inicial
# Proyecto: curso_python
# Autor: Analu
# Objetivo: repasar flujo básico de análisis de datos en Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
np.random.seed(42)

df = pd.DataFrame({
    "edad": np.random.randint(18, 65, 100),
    "ingreso": np.random.normal(30000, 8000, 100),
    "departamento": np.random.choice(["Ventas", "IT", "HR", "Marketing"], 100)
})

df.head()
# Out:
#    edad       ingreso departamento
# 0    56  35090.440867    Marketing
# 1    46  22746.234651           IT
# 2    32  33808.340699    Marketing
# 3    60  40429.290147       Ventas
# 4    25  31692.696099    Marketing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   edad          100 non-null    int32
#  1   ingreso       100 non-null    float64
#  2   departamento  100 non-null    object
# dtypes: float64(1), int32(1), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# describe() te da un resumen estadístico rápido de tus datos numéricos.
# Sirve para entender el dataset en segundos, sin calcular nada a mano.
# ¿Qué información devuelve?
#
# Para columnas numéricas, muestra:
#
# Métrica     Qué significa	                  Para qué sirve
# count	    Cantidad de valores NO nulos        Detectar datos faltantes
# mean	    Promedio	                        Nivel típico
# std	        Desviación estándar	                Variabilidad
# min	        Valor mínimo	                    Detectar errores/outliers
# 25%	        Primer cuartil	                    Distribución
# 50%	        Mediana                         	Valor central real
# 75%	        Tercer cuartil	                    Distribución
# max	        Valor máximo	                    Detectar outliers

# %%
df.describe()
# Out:
#             edad       ingreso
# count  100.00000    100.000000
# mean    40.88000  30548.076349
# std     13.99082   7981.782445
# min     18.00000  14480.710251
# 25%     30.50000  23876.152353
# 50%     41.00000  29930.787232
# 75%     53.25000  36026.789420
# max     64.00000  53549.307332

# %%
plt.figure()
sns.histplot(df["edad"], bins=15)
plt.title("Distribución de edades")
plt.show()
